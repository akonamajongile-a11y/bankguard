# %% [markdown]
# # Cleaning Fraud Labels Data

# %%
import pandas as pd

fraud_labels = pd.read_csv("../data/raw/fraud_labels.csv")
fraud_labels
# Out:
#         transaction_id  is_fraud fraud_reason
# 0                    1         0          NaN
# 1                    2         0          NaN
# 2                    3         0          NaN
# 3                    4         0          NaN
# 4                    5         0          NaN
# ...                ...       ...          ...
# 999995          999996         0          NaN
# 999996          999997         0          NaN
# 999997          999998         0          NaN
# 999998          999999         0          NaN
# 999999         1000000         0          NaN
#
# [1000000 rows x 3 columns]

# %%
fraud_labels.info()

fraud_labels.describe(include='all')
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 3 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   transaction_id  1000000 non-null  int64
#  1   is_fraud        1000000 non-null  int64
#  2   fraud_reason    24260 non-null    str
# dtypes: int64(2), str(1)
# memory usage: 22.9 MB
#         transaction_id        is_fraud fraud_reason
# count   1000000.000000  1000000.000000        24260
# unique             NaN             NaN           33
# top                NaN             NaN         nan
# freq               NaN             NaN         6034
# mean     499999.788612        0.006389          NaN
# std      288677.403098        0.079676          NaN
# min           1.000000        0.000000          NaN
# 25%      249990.750000        0.000000          NaN
# 50%      500018.500000        0.000000          NaN
# 75%      750002.250000        0.000000          NaN
# max     1000000.000000        1.000000          NaN

# %%
# Check fraud distribution
fraud_labels['is_fraud'].value_counts()
# Out:
# is_fraud
# 0    993611
# 1      6389
# Name: count, dtype: int64

# %%
# Missing values
fraud_labels.isnull().sum()
# Out:
# transaction_id         0
# is_fraud               0
# fraud_reason      975740
# dtype: int64

# %%
# Non-fraud transactions with a fraud reason
invalid_1 = fraud_labels[(fraud_labels['is_fraud'] == 0) & (fraud_labels['fraud_reason'].notna())]

# Fraud transactions without a fraud reason
invalid_2 = fraud_labels[(fraud_labels['is_fraud'] == 1) & (fraud_labels['fraud_reason'].isna())]

print(len(invalid_1))
print(len(invalid_2))
# Out:
# 17902
# 31

# %%
#handling missing values
fraud_labels.loc[
(fraud_labels['is_fraud'] == 1) & (fraud_labels['fraud_reason'].isna()),
'fraud_reason'
] = 'Unknown'

# %%
#keep NaN or replace with a label
fraud_labels['fraud_reason'] = fraud_labels['fraud_reason'].fillna('No Fraud')

# %%
# removing duplicates
fraud_labels = fraud_labels.drop_duplicates()

fraud_labels[fraud_labels.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [transaction_id, is_fraud, fraud_reason]
# Index: []

# %%
# ensuring ID's unique
fraud_labels['transaction_id'].nunique()

fraud_labels.shape[0]
# Out:
# 999059

# %%
# finding duplicates
"fraud_labels.duplicated()"
# Out:
# 'fraud_labels.duplicated()'

# %%
# correcting data types
fraud_labels['transaction_id'] = fraud_labels['transaction_id'].astype(float)
fraud_labels['is_fraud'] = fraud_labels['is_fraud'].astype(float)
fraud_labels.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 999059 entries, 0 to 999999
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   transaction_id  999059 non-null  float64
#  1   is_fraud        999059 non-null  float64
#  2   fraud_reason    999059 non-null  str
# dtypes: float64(2), str(1)
# memory usage: 30.5 MB

# %%
# standardazing
fraud_labels['fraud_reason'] = (
fraud_labels['fraud_reason']
.str.strip()
.str.lower()
)
fraud_labels
# Out:
#         transaction_id  is_fraud fraud_reason
# 0                  1.0       0.0     no fraud
# 1                  2.0       0.0     no fraud
# 2                  3.0       0.0     no fraud
# 3                  4.0       0.0     no fraud
# 4                  5.0       0.0     no fraud
# ...                ...       ...          ...
# 999995        999996.0       0.0     no fraud
# 999996        999997.0       0.0     no fraud
# 999997        999998.0       0.0     no fraud
# 999998        999999.0       0.0     no fraud
# 999999       1000000.0       0.0     no fraud
#
# [999059 rows x 3 columns]

# %%
# Validation
print(fraud_labels.isnull().sum())
print(fraud_labels['is_fraud'].value_counts())

# Check for invalid combinations again
fraud_labels[
((fraud_labels['is_fraud'] == 0) & (fraud_labels['fraud_reason'] != 'No Fraud'))
]
# Out:
# transaction_id    0
# is_fraud          0
# fraud_reason      0
# dtype: int64
# is_fraud
# 0.0    992670
# 1.0      6389
# Name: count, dtype: int64
#         transaction_id  is_fraud fraud_reason
# 0                  1.0       0.0     no fraud
# 1                  2.0       0.0     no fraud
# 2                  3.0       0.0     no fraud
# 3                  4.0       0.0     no fraud
# 4                  5.0       0.0     no fraud
# ...                ...       ...          ...
# 999995        999996.0       0.0     no fraud
# 999996        999997.0       0.0     no fraud
# 999997        999998.0       0.0     no fraud
# 999998        999999.0       0.0     no fraud
# 999999       1000000.0       0.0     no fraud
#
# [992670 rows x 3 columns]

# %%
fraud_labels.to_csv("../Data/processed/fraud_label_cleaned.csv", index=False)

# %% [markdown]
# # Cleaning Merchants Data

# %%
import pandas as pd

merchants = pd.read_csv("../data/raw/merchants.csv")
merchants.info()
merchants
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   merchant_id        20000 non-null  int64
#  1   merchant_name      20000 non-null  str
#  2   merchant_category  19881 non-null  str
#  3   province           20000 non-null  str
#  4   city               19878 non-null  str
#  5   risk_rating        19869 non-null  str
# dtypes: int64(1), str(5)
# memory usage: 937.6 KB
#        merchant_id    merchant_name merchant_category       province  \
# 0                1   merchant 00001   Online Services     Free State
# 1                2   Merchant 00002           Grocery     Mpumalanga
# 2                3   Merchant 00003          Clothing        Limpopo
# 3                4   Merchant 00004           Grocery     Mpumalanga
# 4                5   Merchant 00005            Travel     Free State
# ...            ...              ...               ...            ...
# 19995        19996   Merchant 19996  Online  Services     Mpumalanga
# 19996        19997   Merchant 19997        Restaurant  KwaZulu-Natal
# 19997        19998  Merchant  19998           Grocery  KwaZulu-Natal
# 19998        19999   Merchant 19999           Grocery     Free State
# 19999        20000   Merchant 20000  Online  Services     Mpumalanga
#
#                city risk_rating
# 0         Bethlehem         Low
# 1           Secunda         Low
# 2         Polokwane      Medium
# 3          Mbombela         Low
# 4      Bloemfontein      Medium
# ...             ...         ...
# 19995      Mbombela         Low
# 19996        Durban         Low
# 19997  Richards Bay         Low
# 19998       Welkom          Low
# 19999      Mbombela        High
#
# [20000 rows x 6 columns]

# %%
# #This helps identify spelling inconsistencies.

merchants.city = merchants.city.str.strip()
# # merchants the white and space bar space
merchants['city'] = merchants['city'].str.replace(r'\s+', ' ', regex= True)
merchants.city = merchants.city.str.title()

# merchants.city.unique()

merchants.city.unique()
# Out:
# <StringArray>
# [       'Bethlehem',          'Secunda',        'Polokwane',
#          'Mbombela',     'Bloemfontein', 'Pietermaritzburg',
#      'Johannesburg',         'Gqeberha',       'Klerksdorp',
#      'Stellenbosch',           'Welkom',       'Rustenburg',
#          'Mahikeng',      'Thohoyandou',       'Emalahleni',
#            'Durban',          'Midrand',     'Richards Bay',
#       'East London',         'Pretoria',         'Upington',
#           'Mthatha',           'George',            'Paarl',
#            'Soweto',        'Kimberley',          'Tzaneen',
#                 nan,          'Kuruman',        'Cape Town']
# Length: 30, dtype: str

# %%
merchants.province= merchants.province.str.strip()
# # merchants the white and space bar space
merchants['province'] = merchants['province'].str.replace("  ", " ")
merchants.province = merchants.province.str.title()


# #Expected provinces
merchants.province.unique()
# Out:
# <StringArray>
# [   'Free State',    'Mpumalanga',       'Limpopo', 'Kwazulu-Natal',
#        'Gauteng',  'Eastern Cape',    'North West',  'Western Cape',
#  'Northern Cape']
# Length: 9, dtype: str

# %%
merchants.merchant_category= merchants.merchant_category.str.strip()
# # merchants the white and space bar space
merchants['merchant_category'] = merchants['merchant_category'].str.replace("  ", " ")
merchants.merchant_category = merchants.merchant_category.str.title()
merchants.merchant_category.unique()
# Out:
# <StringArray>
# ['Online Services',         'Grocery',        'Clothing',          'Travel',
#    'Entertainment',            'Fuel',      'Healthcare',     'Electronics',
#            'Other',      'Restaurant',               nan]
# Length: 11, dtype: str

# %%
merchants.risk_rating= merchants.risk_rating.str.strip()
# # merchants the white and space bar space
merchants['risk_rating'] = merchants['risk_rating'].str.replace("  ", " ")
merchants.risk_rating = merchants.risk_rating.str.title()
merchants.risk_rating.unique()
# Out:
# <StringArray>
# ['Low', 'Medium', 'High', 'Critical', 'High Risk', nan, 'Unknown']
# Length: 7, dtype: str

# %%
# replacing null values with"Nan"
import numpy as np
merchants = merchants.replace(np.nan, "Nan")

# %%
merchants.isnull().sum()
# Out:
# merchant_id          0
# merchant_name        0
# merchant_category    0
# province             0
# city                 0
# risk_rating          0
# dtype: int64

# %%
# Showing the entire row duplicates
merchants.duplicated().sum()

# since the merchant id are unique
merchants['merchant_id'].duplicated().sum()

#viewing duplicates
merchants[merchants['merchant_id'].duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [merchant_id, merchant_name, merchant_category, province, city, risk_rating]
# Index: []

# %%
# Removing the duplicates
merchants = merchants.drop_duplicates()

merchants[merchants.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [merchant_id, merchant_name, merchant_category, province, city, risk_rating]
# Index: []

# %%
merchants.province = merchants.province.str.replace(r'\s+', ' ', regex=True)
merchants.province.unique()
# Out:
# <StringArray>
# [   'Free State',    'Mpumalanga',       'Limpopo', 'Kwazulu-Natal',
#        'Gauteng',  'Eastern Cape',    'North West',  'Western Cape',
#  'Northern Cape']
# Length: 9, dtype: str

# %%
print(merchants.info())
print(merchants.isnull().sum())
print(merchants.duplicated().sum())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   merchant_id        20000 non-null  int64
#  1   merchant_name      20000 non-null  str
#  2   merchant_category  20000 non-null  str
#  3   province           20000 non-null  str
#  4   city               20000 non-null  str
#  5   risk_rating        20000 non-null  str
# dtypes: int64(1), str(5)
# memory usage: 937.6 KB
# None
# merchant_id          0
# merchant_name        0
# merchant_category    0
# province             0
# city                 0
# risk_rating          0
# dtype: int64
# 0

# %%
merchants.to_csv("../Data/processed/merchants_cleaned.csv", index=False)

# %% [markdown]
# # Date Feature Engineering

# %%
# Convert to datetime first
import pandas as pd

customers = pd.read_csv("../data/processed/cleanedCustomers2.csv")
customers
#customers['transaction_date'] == pd.to_datetime(customers['transaction_date'])
# Out:
#         Unnamed: 0  customer_id first_name last_name  age       province  \
# 0                0            1       Emma    Naidoo   42     Free State
# 1                1            2     Amelia   Mokoena   49     Mpumalanga
# 2                2            3      Nomsa    Jacobs   34     North West
# 3                3            4      Sipho   Dlamini   35  Kwazulu-Natal
# 4                4            5       Emma    Molefe   33  Kwazulu-Natal
# ...            ...          ...        ...       ...  ...            ...
# 100085      100388        40659     Sophia     Botha   39   Eastern Cape
# 100086      100390        93542       Noah    Jacobs   41        Gauteng
# 100087      100392        89556     Lerato    Botha    33  Kwazulu-Natal
# 100088      100393        55437       Noah     Botha   56        Gauteng
# 100089      100394        85139       Noah   Mokoena   51   Eastern Cape
#
#                 city employment_status    income customer_since
# 0       Bloemfontein          Employed  11418.82     2022-11-24
# 1           Mbombela               Nan  31336.45     2024-12-25
# 2         Rustenburg          Employed  11351.46     2020-03-18
# 3             Durban           Retired  30291.15     2025-10-21
# 4             Durban          Employed  28803.42     2013-10-02
# ...              ...               ...       ...            ...
# 100085      Gqeberha          Employed  15477.05     2025-02-03
# 100086  Johannesburg           Student      0.00     2016-12-26
# 100087        Durban        Unemployed  21132.74     2021-08-28
# 100088        Soweto           Retired  31652.89     2016-08-19
# 100089       Mthatha          Employed   8714.87     2013-07-17
#
# [100090 rows x 10 columns]

# %%
#Converting customer_since data type to datetime and fixing date format
#customers['customer_since'] = customer['customer-since'].str.replace("-","/")

customers['customer_since'] = pd.to_datetime(customers['customer_since'],
format='mixed',
errors='coerce')

# %%
customers['Start_Year'] = customers.customer_since.dt.year
customers
# Out:
#         Unnamed: 0  customer_id first_name last_name  age       province  \
# 0                0            1       Emma    Naidoo   42     Free State
# 1                1            2     Amelia   Mokoena   49     Mpumalanga
# 2                2            3      Nomsa    Jacobs   34     North West
# 3                3            4      Sipho   Dlamini   35  Kwazulu-Natal
# 4                4            5       Emma    Molefe   33  Kwazulu-Natal
# ...            ...          ...        ...       ...  ...            ...
# 100085      100388        40659     Sophia     Botha   39   Eastern Cape
# 100086      100390        93542       Noah    Jacobs   41        Gauteng
# 100087      100392        89556     Lerato    Botha    33  Kwazulu-Natal
# 100088      100393        55437       Noah     Botha   56        Gauteng
# 100089      100394        85139       Noah   Mokoena   51   Eastern Cape
#
#                 city employment_status    income customer_since  Start_Year
# 0       Bloemfontein          Employed  11418.82     2022-11-24        2022
# 1           Mbombela               Nan  31336.45     2024-12-25        2024
# 2         Rustenburg          Employed  11351.46     2020-03-18        2020
# 3             Durban           Retired  30291.15     2025-10-21        2025
# 4             Durban          Employed  28803.42     2013-10-02        2013
# ...              ...               ...       ...            ...         ...
# 100085      Gqeberha          Employed  15477.05     2025-02-03        2025
# 100086  Johannesburg           Student      0.00     2016-12-26        2016
# 100087        Durban        Unemployed  21132.74     2021-08-28        2021
# 100088        Soweto           Retired  31652.89     2016-08-19        2016
# 100089       Mthatha          Employed   8714.87     2013-07-17        2013
#
# [100090 rows x 11 columns]

# %%
customers['Start_Month'] = customers.customer_since.dt.month

# %%
customers['Start_Day'] = customers.customer_since.dt.day

# %%
customers['Weekday'] = customers.customer_since.dt.weekday
customers
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100090 entries, 0 to 100089
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         100090 non-null  int64
#  1   customer_id        100090 non-null  int64
#  2   first_name         100090 non-null  str
#  3   last_name          100090 non-null  str
#  4   age                100090 non-null  int64
#  5   province           100090 non-null  str
#  6   city               100090 non-null  str
#  7   employment_status  100090 non-null  str
#  8   income             100090 non-null  float64
#  9   customer_since     100090 non-null  datetime64[us]
#  10  Start_Year         100090 non-null  int32
#  11  Start_Month        100090 non-null  int32
#  12  Start_Day          100090 non-null  int32
#  13  Weekday            100090 non-null  int32
# dtypes: datetime64[us](1), float64(1), int32(4), int64(3), str(5)
# memory usage: 9.2 MB

# %%
customers.to_csv("cleanedCustomers2.csv", index=False)

# %% [markdown]
# # Fraud Features

# %%
import pandas as pd

# %%
accounts = pd.read_csv("../data/processed/cleanedAccounts2.csv")
transactions = pd.read_csv("../data/final/transactions_clean_final.csv")

# %%
accounts = accounts.account_id.astype(str)

# %%
trans_acc = pd.merge(accounts,transactions, how='inner')

# %%
trans_acc.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 994216 entries, 0 to 994215
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   account_id        994216 non-null  str
#  1   Unnamed: 0        994216 non-null  int64
#  2   transaction_id    994216 non-null  int64
#  3   merchant_id       994216 non-null  str
#  4   transaction_date  994216 non-null  str
#  5   transaction_type  994216 non-null  str
#  6   channel           994216 non-null  str
#  7   amount            994216 non-null  float64
#  8   currency          994216 non-null  str
#  9   description       994216 non-null  str
#  10  transaction_size  994216 non-null  str
#  11  transaction_days  994216 non-null  str
#  12  transaction_year  994216 non-null  int64
# dtypes: float64(1), int64(3), str(9)
# memory usage: 98.6 MB

# %%
pd.DataFrame(trans_acc.groupby("account_id")['account_id'].count())
pd.DataFrame(trans_acc.groupby("account_id")['amount'].sum())
# Out:
#               amount
# account_id
# 1           14227.60
# 10           3558.06
# 100         23835.02
# 1000        12908.30
# 10000        8214.49
# ...              ...
# 99995        5686.28
# 99996        4937.56
# 99997       10202.72
# 99998        7616.06
# 99999        8442.60
#
# [124343 rows x 1 columns]

# %%
trans_acc = pd.merge(customers,transactions, how='inner')

# %%
trans_acc['customer_average'] = trans_acc.groupby('customer_id')['amount'].transform('mean')
transactions.info()

trans_acc['amount_vs_customer_average'] = (
trans_acc['amount'] / trans_acc['customer_average']
)
transactions
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1001065 entries, 0 to 1001064
# Data columns (total 13 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Unnamed: 0        1001065 non-null  int64
#  1   transaction_id    1001065 non-null  int64
#  2   account_id        1001065 non-null  str
#  3   merchant_id       1001065 non-null  str
#  4   transaction_date  1001065 non-null  str
#  5   transaction_type  1001065 non-null  str
#  6   channel           1001065 non-null  str
#  7   amount            1001065 non-null  float64
#  8   currency          1001065 non-null  str
#  9   description       1001065 non-null  str
#  10  transaction_size  1001065 non-null  str
#  11  transaction_days  1001065 non-null  str
#  12  transaction_year  1001065 non-null  int64
# dtypes: float64(1), int64(3), str(9)
# memory usage: 99.3 MB
#          Unnamed: 0  transaction_id account_id merchant_id transaction_date  \
# 0                 0               1      65820     19009.0       2025-05-26
# 1                 1               2       9167     15505.0       2026-05-06
# 2                 2               3      86080     12053.0       2025-12-24
# 3                 3               4      56039     10816.0       2025-10-05
# 4                 4               5      69271      9603.0       2025-01-27
# ...             ...             ...        ...         ...              ...
# 1001060     1002984          554267      41324     17708.0       2025-05-08
# 1001061     1002989          321736      13591     Unknown       2026-07-24
# 1001062     1002990          341329      58456     14524.0       2025-02-05
# 1001063     1002997          210561      42406      4358.0       2025-10-31
# 1001064     1002999           46641      82526      3556.0       2025-08-28
#
#         transaction_type channel   amount currency      description  \
# 0                Deposit     Pos   448.44        R         Transfer
# 1               Purchase     Atm    85.00        R  Online purchase
# 2                Payment     Atm   459.94        R  Retail purchase
# 3               Transfer  Mobile   511.36        R     Bill payment
# 4                Deposit  Mobile   362.61        R     Bill payment
# ...                  ...     ...      ...      ...              ...
# 1001060          Payment     Pos   156.88        R         Transfer
# 1001061         Purchase  Mobile  1438.58        R  Online purchase
# 1001062          Deposit     Atm  1017.77        R     Bill payment
# 1001063       Withdrawal     Pos   189.00        R  Online purchase
# 1001064         Transfer     Pos  3318.48        R           Salary
#
#         transaction_size transaction_days  transaction_year
# 0                    Low           Monday              2025
# 1                    Low        Wednesday              2026
# 2                    Low        Wednesday              2025
# 3                    Low           Sunday              2025
# 4                    Low           Monday              2025
# ...                  ...              ...               ...
# 1001060              Low         Thursday              2025
# 1001061              Low           Friday              2026
# 1001062              Low        Wednesday              2025
# 1001063              Low           Friday              2025
# 1001064              Low         Thursday              2025
#
# [1001065 rows x 13 columns]

# %% [markdown]
# # Customer Analytics

# %%
import pandas as pd

customers = pd.read_csv("../data/final/customers_final.csv")
customers
# Out:
#         customer_id first_name last_name  age       province          city  \
# 0                 1       Emma    Naidoo   42     Free State  Bloemfontein
# 1                 2     Amelia   Mokoena   49     Mpumalanga      Mbombela
# 2                 3      Nomsa    Jacobs   34     North West    Rustenburg
# 3                 4      Sipho   Dlamini   35  Kwazulu-Natal        Durban
# 4                 5       Emma    Molefe   33  Kwazulu-Natal        Durban
# ...             ...        ...       ...  ...            ...           ...
# 100085        40659     Sophia     Botha   39   Eastern Cape      Gqeberha
# 100086        93542       Noah    Jacobs   41        Gauteng  Johannesburg
# 100087        89556     Lerato    Botha    33  Kwazulu-Natal        Durban
# 100088        55437       Noah     Botha   56        Gauteng        Soweto
# 100089        85139       Noah   Mokoena   51   Eastern Cape       Mthatha
#
#        employment_status    income customer_since  Start_Year  Start_Month  \
# 0               Employed  11418.82     2022-11-24        2022           11
# 1                    Nan  31336.45     2024-12-25        2024           12
# 2               Employed  11351.46     2020-03-18        2020            3
# 3                Retired  30291.15     2025-10-21        2025           10
# 4               Employed  28803.42     2013-10-02        2013           10
# ...                  ...       ...            ...         ...          ...
# 100085          Employed  15477.05     2025-02-03        2025            2
# 100086           Student      0.00     2016-12-26        2016           12
# 100087        Unemployed  21132.74     2021-08-28        2021            8
# 100088           Retired  31652.89     2016-08-19        2016            8
# 100089          Employed   8714.87     2013-07-17        2013            7
#
#         Start_Day  Weekday  cus_trans_count  cus_total_trans_val  \
# 0              24        3             20.0             17160.30
# 1              25        2             15.0             14705.83
# 2              18        2              8.0              7736.72
# 3              21        1             42.0             32623.01
# 4               2        2             12.0              9224.98
# ...           ...      ...              ...                  ...
# 100085          3        0             56.0             57030.38
# 100086         26        0             28.0             32166.68
# 100087         28        5              NaN                  NaN
# 100088         19        4              NaN                  NaN
# 100089         17        2             14.0              9177.28
#
#         customer_avg_trans  cus_max_trans
# 0               858.015000        3553.98
# 1               980.388667        2131.47
# 2               967.090000        1772.57
# 3               776.738333        2430.00
# 4               768.748333        1917.57
# ...                    ...            ...
# 100085         1018.399643        3517.65
# 100086         1148.810000        4132.44
# 100087                 NaN            NaN
# 100088                 NaN            NaN
# 100089          655.520000        1709.05
#
# [100090 rows x 17 columns]

# %%
#How many customers does the bank have?
total_customers =customers['customer_id'].nunique()
print(f"Total customers: {total_customers}")
# Out:
# Total customers: 99903

# %%
import matplotlib.pyplot as plt

total_customers = trans_acc['customer_id'].nunique()

fig, ax = plt.subplots(figsize=(6,3))
ax.axis('off')

ax.text(
    0.5, 0.6,
    f'{total_customers:,}',
    fontsize=30,
    fontweight='bold',
    ha='center'
)

ax.text(
0.5, 0.3,
'Total Customers',
fontsize=14,
ha='center'
)

plt.show()

# %%
#Which province has the most customers?
province_customers = (
trans_acc.groupby('province')['customer_id'].nunique().sort_values(ascending=False)
)
print(province_customers)
print("Province with most customers:", province_customers.idxmax())
# Out:
# province
# Gauteng          29831
# Kwazulu-Natal    20064
# Western Cape     11945
# Eastern Cape     10102
# Limpopo           7938
# Free State        6040
# Mpumalanga        5987
# North West        5077
# Northern Cape     3004
# Name: customer_id, dtype: int64
# Province with most customers: Gauteng

# %%
g = list(province_customers.index.values)[0:]
v = list(province_customers.values)[0:]
g
# Out:
# ['Gauteng',
#  'Kwazulu-Natal',
#  'Western Cape',
#  'Eastern Cape',
#  'Limpopo',
#  'Free State',
#  'Mpumalanga',
#  'North West',
#  'Northern Cape']

# %%
import matplotlib.pyplot as plt

# create bar graph
plt.bar(g, v, color="hotpink", edgecolor='black')

# formatting
plt.title('Province with most customers')
plt.xlabel('No. of Customers')
plt.ylabel('Pronvinces')
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Gauteng'),
#   Text(1, 0, 'Kwazulu-Natal'),
#   Text(2, 0, 'Western Cape'),
#   Text(3, 0, 'Eastern Cape'),
#   Text(4, 0, 'Limpopo'),
#   Text(5, 0, 'Free State'),
#   Text(6, 0, 'Mpumalanga'),
#   Text(7, 0, 'North West'),
#   Text(8, 0, 'Northern Cape')])

# %%
import pandas as pd

accounts = pd.read_csv("../data/processed/cleanedAccounts2.csv")
accounts
# Out:
#         account_id  customer_id account_type  branch_id account_status  \
# 0                1        74688     Business        150         Active
# 1                2        21183      Savings         54         Active
# 2                3        93719       Cheque        164         Active
# 3                4         6909       Cheque         36         Active
# 4                5        45524       Cheque         86         Active
# ...            ...          ...          ...        ...            ...
# 124396       44719            0       Cheque        195         Active
# 124397       75601        43076     Business        115            Nan
# 124398       38511        65749          Nan        142         Active
# 124399       55160        20760          Nan         72         Active
# 124400      112560        93769      Savings         76         Active
#
#        opened_date
# 0       2017-06-28
# 1       2021-01-26
# 2       2023-01-13
# 3       2017-12-30
# 4       2021-02-21
# ...            ...
# 124396  2022-02-17
# 124397  2023-12-15
# 124398  2016-12-05
# 124399  2023-09-19
# 124400  2018-12-18
#
# [124401 rows x 6 columns]

# %%
# Which account type is most popular:
account_type = (
accounts.groupby('account_type')['customer_id'].nunique().sort_values(ascending=False)
)
print(account_type)
print("Most popular account type:", account_type.idxmax())
# Out:
# account_type
# Savings     40564
# Cheque      39068
# Credit      11642
# Business     9563
# Nan           654
# Name: customer_id, dtype: int64
# Most popular account type: Savings

# %%
g = list(account_type.index.values)[0:3]
v = list(account_type.values)[0:3]
g
# Out:
# ['Savings', 'Cheque', 'Credit']

# %%
import matplotlib.pyplot as plt

# create bar graph
plt.bar(g, v, color='hotpink', edgecolor='black')

# formatting
plt.title('Account type with most customers')
plt.xlabel('Account type')
plt.ylabel('No. of Customers')
# Out:
# Text(0, 0.5, 'No. of Customers')

# %%
#Which age group has the highest transaction activity?
#Was creating age groups:
trans_acc['age_group'] = pd.cut(
trans_acc['age'],
bins=[0, 25, 35, 45, 55, 65, 100],
labels=['18-25', '26-35', '36-45', '46-55', '56-65', '65+']
)

#By number of transactions:
activity = trans_acc.groupby('age_group').size().sort_values(ascending=False)
print(activity)
print("Highest transaction activity:", activity.idxmax())

#By number of transactions:
activity = trans_acc.groupby('age_group').size().sort_values(ascending=False)
print(activity)
print("Highest transaction activity:", activity.idxmax())
# Out:
# age_group
# 36-45    29894
# 26-35    24455
# 46-55    20657
# 18-25    14780
# 56-65     8054
# 65+       2093
# dtype: int64
# Highest transaction activity: 36-45
# age_group
# 36-45    29894
# 26-35    24455
# 46-55    20657
# 18-25    14780
# 56-65     8054
# 65+       2093
# dtype: int64
# Highest transaction activity: 36-45

# %%
import pandas as pd

customers = pd.read_csv("../data/final/customers_final.csv")
customers
# Out:
#         customer_id first_name last_name  age       province          city  \
# 0                 1       Emma    Naidoo   42     Free State  Bloemfontein
# 1                 2     Amelia   Mokoena   49     Mpumalanga      Mbombela
# 2                 3      Nomsa    Jacobs   34     North West    Rustenburg
# 3                 4      Sipho   Dlamini   35  Kwazulu-Natal        Durban
# 4                 5       Emma    Molefe   33  Kwazulu-Natal        Durban
# ...             ...        ...       ...  ...            ...           ...
# 100085        40659     Sophia     Botha   39   Eastern Cape      Gqeberha
# 100086        93542       Noah    Jacobs   41        Gauteng  Johannesburg
# 100087        89556     Lerato    Botha    33  Kwazulu-Natal        Durban
# 100088        55437       Noah     Botha   56        Gauteng        Soweto
# 100089        85139       Noah   Mokoena   51   Eastern Cape       Mthatha
#
#        employment_status    income customer_since  Start_Year  Start_Month  \
# 0               Employed  11418.82     2022-11-24        2022           11
# 1                    Nan  31336.45     2024-12-25        2024           12
# 2               Employed  11351.46     2020-03-18        2020            3
# 3                Retired  30291.15     2025-10-21        2025           10
# 4               Employed  28803.42     2013-10-02        2013           10
# ...                  ...       ...            ...         ...          ...
# 100085          Employed  15477.05     2025-02-03        2025            2
# 100086           Student      0.00     2016-12-26        2016           12
# 100087        Unemployed  21132.74     2021-08-28        2021            8
# 100088           Retired  31652.89     2016-08-19        2016            8
# 100089          Employed   8714.87     2013-07-17        2013            7
#
#         Start_Day  Weekday  cus_trans_count  cus_total_trans_val  \
# 0              24        3             20.0             17160.30
# 1              25        2             15.0             14705.83
# 2              18        2              8.0              7736.72
# 3              21        1             42.0             32623.01
# 4               2        2             12.0              9224.98
# ...           ...      ...              ...                  ...
# 100085          3        0             56.0             57030.38
# 100086         26        0             28.0             32166.68
# 100087         28        5              NaN                  NaN
# 100088         19        4              NaN                  NaN
# 100089         17        2             14.0              9177.28
#
#         customer_avg_trans  cus_max_trans
# 0               858.015000        3553.98
# 1               980.388667        2131.47
# 2               967.090000        1772.57
# 3               776.738333        2430.00
# 4               768.748333        1917.57
# ...                    ...            ...
# 100085         1018.399643        3517.65
# 100086         1148.810000        4132.44
# 100087                 NaN            NaN
# 100088                 NaN            NaN
# 100089          655.520000        1709.05
#
# [100090 rows x 17 columns]

# %%
g = list(activity.index.values)[0:]
v = list(activity.values)[0:]
g
# Out:
# ['36-45', '26-35', '46-55', '18-25', '56-65', '65+']

# %%
#Which employment group has the highest average income?
avg_income = (
trans_acc.groupby('employment_status')['income']
.mean()
.sort_values(ascending=False)
)
print(avg_income)
print("Highest average income:", avg_income.idxmax())
# Out:
# employment_status
# Retired          26408.372536
# Employed         26383.996189
# Self-employed    26379.438914
# Student          26293.854490
# Nan              26272.111514
# Unemployed       26189.167557
# Name: income, dtype: float64
# Highest average income: Retired

# %%
import matplotlib.pyplot as plt

# create bar graph
plt.bar(g, v, color='hotpink', edgecolor='black')

# formatting
plt.title('Employment group that have highest average income')
plt.xlabel('Age group')
plt.ylabel('Activity')
# Out:
# Text(0, 0.5, 'Activity')

# %%
# Which customer segments generate the highest transaction value
bins = [0, 10000, 30000, 60000, float('inf')]
labels = ['Low Income', 'Middle Income', 'High Income', 'Very High Income']

customers['customer_segment'] = pd.cut(
    customers['income'],
    bins=bins,
    labels=labels
)

segment_value = customers.groupby('customer_segment')['cus_total_trans_val'].sum().sort_values(ascending=False).reset_index()#

print(segment_value)
# Out:
#    customer_segment  cus_total_trans_val
# 0     Middle Income         4.365035e+09
# 1       High Income         1.551074e+09
# 2        Low Income         8.146618e+08
# 3  Very High Income         4.148204e+08

# %%
g = list(segment_value.index.values)[0:]
v = list(segment_value.values)[0:]
g
# Out:
# [np.int64(0), np.int64(1), np.int64(2), np.int64(3)]

# %%
import matplotlib.pyplot as plt

# Create bar graph
plt.figure(figsize=(8, 5))
plt.bar(
segment_value['customer_segment'],
segment_value['cus_total_trans_val'],
color='hotpink', edgecolor='black'
)

# Formatting
plt.title('Total Transaction Value by Customer Segment')
plt.xlabel('Customer Segment')
plt.ylabel('Total Transaction Value($)')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
customers.to_csv("customer_final.csv", index=False)

# %%
import pandas as pd
customers = pd.read_csv("customer_final.csv")
customers.head()
# Out:
#    customer_id first_name last_name  age       province          city  \
# 0            1       Emma    Naidoo   42     Free State  Bloemfontein
# 1            2     Amelia   Mokoena   49     Mpumalanga      Mbombela
# 2            3      Nomsa    Jacobs   34     North West    Rustenburg
# 3            4      Sipho   Dlamini   35  Kwazulu-Natal        Durban
# 4            5       Emma    Molefe   33  Kwazulu-Natal        Durban
#
#   employment_status    income customer_since  Start_Year  Start_Month  \
# 0          Employed  11418.82     2022-11-24        2022           11
# 1               Nan  31336.45     2024-12-25        2024           12
# 2          Employed  11351.46     2020-03-18        2020            3
# 3           Retired  30291.15     2025-10-21        2025           10
# 4          Employed  28803.42     2013-10-02        2013           10
#
#    Start_Day  Weekday  cus_trans_count  cus_total_trans_val  \
# 0         24        3             20.0             17160.30
# 1         25        2             15.0             14705.83
# 2         18        2              8.0              7736.72
# 3         21        1             42.0             32623.01
# 4          2        2             12.0              9224.98
#
#    customer_avg_trans  cus_max_trans customer_segment
# 0          858.015000        3553.98    Middle Income
# 1          980.388667        2131.47      High Income
# 2          967.090000        1772.57    Middle Income
# 3          776.738333        2430.00      High Income
# 4          768.748333        1917.57    Middle Income
